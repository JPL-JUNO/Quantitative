# %%
# %load_ext zipline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_line_magic('load_ext', 'zipline')
#
# File d:\anaconda3\envs\ML4T\lib\site-packages\IPython\core\interactiveshell.py:2417, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2415     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2416 with self.builtin_trap:
# -> 2417     result = fn(*args, **kwargs)
#    2419 # The code below prevents the output from being displayed
#    2420 # when using magics with decodator @output_can_be_silenced
#    2421 # when the last Python token in the expression is a ';'.
#    2422 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File d:\anaconda3\envs\ML4T\lib\site-packages\IPython\core\magics\extension.py:33, in ExtensionMagics.load_ext(self, module_str)
#      31 if not module_str:
# ...
